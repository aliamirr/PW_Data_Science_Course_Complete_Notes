# %%
import requests
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone12pro"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
urlclient = urlopen(flipkart_url)

# %%
urlclient

# %%
page_flipkart = urlclient.read()

# %%
urlclient.close()

# %%
from bs4 import BeautifulSoup as soup

# %%
html_flipkart = soup(page_flipkart,'html.parser')

# %%
html_flipkart
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/"+"apple-iphone-12-pro-silver-512-gb/p/itm0ccf9fc219a71?pid=MOBFWBYZ5UY6ZBVA&amp;lid=LSTMOBFWBYZ5UY6ZBVASXARTV&amp;marketplace=FLIPKART&amp;q=iphone+12+pro&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&amp;fm=Search&amp;iid=cf397800-52ec-455a-b4fa-574cbfc12ad9.MOBFWBYZ5UY6ZBVA.SEARCH&amp;ppt=sp&amp;ppn=sp&amp;ssid=x0ghnsnddkk6p5vk1679072049138&amp;qH=8b8a097744d4c19d"
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-silver-512-gb/p/itm0ccf9fc219a71?pid=MOBFWBYZ5UY6ZBVA&amp;lid=LSTMOBFWBYZ5UY6ZBVASXARTV&amp;marketplace=FLIPKART&amp;q=iphone+12+pro&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&amp;fm=Search&amp;iid=cf397800-52ec-455a-b4fa-574cbfc12ad9.MOBFWBYZ5UY6ZBVA.SEARCH&amp;ppt=sp&amp;ppn=sp&amp;ssid=x0ghnsnddkk6p5vk1679072049138&amp;qH=8b8a097744d4c19d'

# %%
bigbox = html_flipkart.findAll("div", {"class":"_1AtVbE col-12-12"})

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone12pro&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=
# ...

# %%
len(bigbox)
# Out:
# 29

# %%
bigbox[3].div.div.div.a['href']
# Out:
# '/apple-iphone-12-pro-gold-256-gb/p/itm43a6a8ee7a1e7?pid=MOBFWBYZ9NGKZS9W&lid=LSTMOBFWBYZ9NGKZS9WYZ2SXA&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=6bea1567-996f-4a9d-a4f3-1ce64fd7d85e.MOBFWBYZ9NGKZS9W.SEARCH&ppt=None&ppn=None&ssid=v85pwpwu0w0000001679630900272&qH=712933e6bd68e7b9'

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
product_req = requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-gold-512-gb/p/itm157b3be191fd1?pid=MOBFWBYZGKFYVTWH&lid=LSTMOBFWBYZGKFYVTWHR65UKC&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_8&otracker=search&fm=organic&iid=6bea1567-996f-4a9d-a4f3-1ce64fd7d85e.MOBFWBYZGKFYVTWH.SEARCH&ppt=None&ppn=None&ssid=v85pwpwu0w0000001679630900272&qH=712933e6bd68e7b9'

# %%
product_html = soup(product_req.text, 'html.parser')

# %%
comment_box = product_html.find_all("div", {"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all('p', {"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Vinit Kar'

# %%
for i in comment_box:
    print(i.div.div.find_all('p', {"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Vinit Kar
# Rahul  Meena
# Nami Hathishah
# Rajesh Jena
# Lee Phela
# Rajkumar tiwari
# Kirti Yadav
# Tushar Saini
# Aasheesh Vats
# Pankaj Mahor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[128], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all('p', {"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 3
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Best in the market!'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Best in the market!
# Highly recommended
# Super!
# Brilliant
# Awesome
# Simply awesome
# Nice
# Fabulous!
# Fabulous!
# Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0].div.text
# Out:
# 'I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!'

# %%
for i in comment_box:
    print(i.div.div.find_all('div',{"class":''})[0].div.text)
# Out:
# I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!
# I like the most in this phone:-1. I like the size of this phone because it is easy to hold.2. The camera quality of this phone is admirable. 3. Battery backup is good.4. The new design and colour  of this phone also a plus point of its beauty.5. These  points are my personal which i like most in this phone.
# One of the best looking phone in the market right now with a decent performance jump from 11 pro. Camera is excellent and the display is quite responsive and sharp. Only issue is it does not have a higher refresh rate and the battery life is average.
# ...

# %%
for i in bigbox:
    print("https://www.flipkart.com" +i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-12-pro-gold-256-gb/p/itm43a6a8ee7a1e7?pid=MOBFWBYZ9NGKZS9W&lid=LSTMOBFWBYZ9NGKZS9WYZ2SXA&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=0cafdb28-a02a-4ff6-bc76-71f5457bafac.MOBFWBYZ9NGKZS9W.SEARCH&ppt=None&ppn=None&ssid=tha5xqzi1s0000001679071664184&qH=712933e6bd68e7b9
# https://www.flipkart.com/apple-iphone-12-pro-silver-128-gb/p/itmaebc8a0edc292?pid=MOBFWBYZSGN526X4&lid=LSTMOBFWBYZSGN526X4XSCKOE&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_6&otracker=search&fm=organic&iid=0cafdb28-a02a-4ff6-bc76-71f5457bafac.MOBFWBYZSGN526X4.SEARCH&ppt=None&ppn=None&ssid=tha5xqzi1s0000001679071664184&qH=712933e6bd68e7b9
# ...
