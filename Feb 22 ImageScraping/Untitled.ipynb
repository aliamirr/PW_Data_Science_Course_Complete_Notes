# %%
import requests
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import logging
# import pymongo
import os

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

# %%
query = "iphone 14"
# response = requests.get(f"https://www.flipkart.com/search?q={query}&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_10_na_na_na&as-pos=2&as-type=RECENT&suggestionId=iphone+12+pro%7CMobiles&requestId=93b3d07c-240c-454b-8a6f-2465d131a0b9&as-searchtext=iPhone%2012%20")
response = requests.get(f"https://www.google.com/search?q={query}&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjH9a3Yg-X9AhUKwjgGHUlEAAMQ_AUoAnoECAEQBA&biw=1200&bih=725&dpr=2")

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml" lang="en-IN"><head><meta content="application/xhtml+xml; charset=UTF-8" http-equiv="Content-Type"/><meta content="no-cache" name="Cache-Control"/><title>iphone 14 - Google Search</title><style>a{text-decoration:none;color:inherit}a:hover{text-decoration:underline}a img{border:0}body{font-family:arial,sans-serif;padding:8px;margin:0 auto;max-width:700px;min-width:240px;}.FbhRzb{border-left:thin solid #dadce0;border-right:thin solid #dadce0;border-top:thin solid #dadce0;height:40px;overflow:hidden}.n692Zd{margin-bottom:10px}.cvifge{height:40px;border-spacing:0}.QvGUP{height:40px;padding:0 8px 0 8px;vertical-align:top}.O4cRJf{height:40px;width:100%;padding:0;padding-right:16px}.O1ePr{height:40px;padding:0;vertical-align:top}.kgJEQe{height:36px;width:98px;vertical-align:top;margin-top:4px}.lXLRf{vertical-align:top}.MhzMZd{border:0;ver
# ...

# %%
new_soup = soup(response.content, 'html.parser')

# %%
new_soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
img_tag = new_soup.find_all("img")

# %%
img_tag
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNn_SP9UGc0dlrxfFtzSlk3pEfjHZ_dSMiScSfHHQEt_Gelzo5ExT_qter0g&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgrrXKuS--dWbmNIr72AZnDI9PGmiHKALhnQ_epXYVTVSrRnKszF2NHrn8HLc&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdneEBc3_r0l7cc3yeeOeHpoSfm_JmCYFpVGhqw7f6aueRtc4Zs0UTz8i75Q&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTm8Oz90IfGAhdb6GMNHHjleD5iNMxvaFEfcFfzjfVmwpuvaKBZ2ncAc5Ex7w&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS_fidMZTrv5ZmzqDVq-oa95Ylq1GAr8YAo8N1tpmekTXgSFBdMDMCSPuvh1A&amp;s"/>,
# ...

# %%
len(img_tag)
# Out:
# 21

# %%
# del img_tag[0:4]
del img_tag[0]

# %%
img_tag
# Out:
# [<img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNn_SP9UGc0dlrxfFtzSlk3pEfjHZ_dSMiScSfHHQEt_Gelzo5ExT_qter0g&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgrrXKuS--dWbmNIr72AZnDI9PGmiHKALhnQ_epXYVTVSrRnKszF2NHrn8HLc&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdneEBc3_r0l7cc3yeeOeHpoSfm_JmCYFpVGhqw7f6aueRtc4Zs0UTz8i75Q&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTm8Oz90IfGAhdb6GMNHHjleD5iNMxvaFEfcFfzjfVmwpuvaKBZ2ncAc5Ex7w&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS_fidMZTrv5ZmzqDVq-oa95Ylq1GAr8YAo8N1tpmekTXgSFBdMDMCSPuvh1A&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTXd9uIA8ROhBrKGZ0MpFT_KnPGAxbhiXtRwitsk7vNLq3ZdDsrufz4u-okdw&amp;s"/>,
# ...

# %%
img_data_mongo = []
for i in img_tag:
    url_img= i['src']
    data_img = requests.get(url_img).content
    mydict = {"index":url_img, "image": data_img}
    img_data_mongo.append(mydict)
    with open(os.path.join(save_dir, f"{query}_{img_tag.index(i)}.jpg"),'wb') as f:
                           f.write(data_img)

# client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")
# db = client['image_scrap']
# coll_img = db['image_scrap']
# coll_img.insert_many(img_data_mongo)
